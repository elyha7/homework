# %%
import matplotlib.pyplot as plt
import numpy as np

ax0, ax1= axes.ravel()
fig, (ax0, ax1) = plt.subplots(ncols=2, sharex=True)
x = np.arange(0.0, 5,0.01)
x1=np.arange(0.0, 3,0.01)
y = np.cos(x)
y1=np.exp(x1)
z1=np.abs(x1)
z=np.sin(x)

ax0.plot(x, y)
ax0.plot(x, z)

ax0.set_title('1a TITLE')
ax0.set_ylabel('3a Ylabel')
ax0.set_xlabel('2a Xlabel ')

ax1.plot(x1, y1)
ax1.plot(x1, z1)

ax1.set_title('1a TITLE')
ax1.set_ylabel('3a Ylabel')
ax1.set_xlabel('2a Xlabel ')

save('pic_1_5_1.pdf', fmt='png')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# example data
x = np.arange(0.1, 4, 0.5)
y = np.exp(-x)
# example error bar values that vary with x-position
error = 0.1 + 0.2 * x
# error bar values w/ different -/+ errors
lower_error = 0.4 * error
upper_error = error
asymmetric_error = [lower_error, upper_error]

fig, (ax0, ax1) = plt.subplots(ncols=2, sharex=True)
ax0.errorbar(x, y, yerr=error, fmt='-o')
ax0.set_title('variable, symmetric error')

ax1.errorbar(x, y, xerr=asymmetric_error, fmt='o')
ax1.set_title('variable, asymmetric error')
ax1.set_yscale('log')
plt.show()
